# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /home/ania/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2)) #stride 2
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten()) #512 =2*2*128
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 128)         32896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 471,610
# Trainable params: 471,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 32s - loss: 1.7658 - acc: 0.3323 - val_loss: 1.4800 - val_acc: 0.4480
#
# Epoch 00001: val_loss improved from inf to 1.47997, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 32s - loss: 1.4335 - acc: 0.4757 - val_loss: 1.2551 - val_acc: 0.5390
#
# Epoch 00002: val_loss improved from 1.47997 to 1.25508, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 31s - loss: 1.3208 - acc: 0.5223 - val_loss: 1.2365 - val_acc: 0.5498
#
# Epoch 00003: val_loss improved from 1.25508 to 1.23653, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 32s - loss: 1.2342 - acc: 0.5562 - val_loss: 1.1198 - val_acc: 0.5916
#
# Epoch 00004: val_loss improved from 1.23653 to 1.11982, saving model to model.weights.best.hdf5
# Epoch 5/50
#  - 32s - loss: 1.1795 - acc: 0.5767 - val_loss: 1.1106 - val_acc: 0.6052
#
# Epoch 00005: val_loss improved from 1.11982 to 1.11063, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 32s - loss: 1.1351 - acc: 0.5961 - val_loss: 1.0613 - val_acc: 0.6212
#
# Epoch 00006: val_loss improved from 1.11063 to 1.06132, saving model to model.weights.best.hdf5
# Epoch 7/50
#  - 31s - loss: 1.0881 - acc: 0.6128 - val_loss: 1.0084 - val_acc: 0.6520
#
# Epoch 00007: val_loss improved from 1.06132 to 1.00838, saving model to model.weights.best.hdf5
# Epoch 8/50
#  - 33s - loss: 1.0600 - acc: 0.6215 - val_loss: 0.9609 - val_acc: 0.6644
#
# Epoch 00008: val_loss improved from 1.00838 to 0.96087, saving model to model.weights.best.hdf5
# Epoch 9/50
#  - 33s - loss: 1.0287 - acc: 0.6350 - val_loss: 0.9634 - val_acc: 0.6636
#
# Epoch 00009: val_loss did not improve from 0.96087
# Epoch 10/50
#  - 33s - loss: 1.0063 - acc: 0.6457 - val_loss: 0.9248 - val_acc: 0.6746
#
# Epoch 00010: val_loss improved from 0.96087 to 0.92478, saving model to model.weights.best.hdf5
# Epoch 11/50
#  - 31s - loss: 0.9836 - acc: 0.6522 - val_loss: 0.9074 - val_acc: 0.6792
#
# Epoch 00011: val_loss improved from 0.92478 to 0.90742, saving model to model.weights.best.hdf5
# Epoch 12/50
#  - 33s - loss: 0.9711 - acc: 0.6607 - val_loss: 0.9005 - val_acc: 0.6874
#
# Epoch 00012: val_loss improved from 0.90742 to 0.90045, saving model to model.weights.best.hdf5
# Epoch 13/50
#  - 31s - loss: 0.9502 - acc: 0.6672 - val_loss: 0.8866 - val_acc: 0.6934
#
# Epoch 00013: val_loss improved from 0.90045 to 0.88662, saving model to model.weights.best.hdf5
# Epoch 14/50
#  - 31s - loss: 0.9314 - acc: 0.6733 - val_loss: 0.9036 - val_acc: 0.6834
#
# Epoch 00014: val_loss did not improve from 0.88662
# Epoch 15/50
#  - 32s - loss: 0.9139 - acc: 0.6802 - val_loss: 0.8861 - val_acc: 0.6940
#
# Epoch 00015: val_loss improved from 0.88662 to 0.88610, saving model to model.weights.best.hdf5
# Epoch 16/50
#  - 32s - loss: 0.8974 - acc: 0.6854 - val_loss: 0.8662 - val_acc: 0.6956
#
# Epoch 00016: val_loss improved from 0.88610 to 0.86621, saving model to model.weights.best.hdf5
# Epoch 17/50
#  - 32s - loss: 0.8882 - acc: 0.6916 - val_loss: 0.8565 - val_acc: 0.7050
#
# Epoch 00017: val_loss improved from 0.86621 to 0.85649, saving model to model.weights.best.hdf5
# Epoch 18/50
#  - 31s - loss: 0.8744 - acc: 0.6952 - val_loss: 0.9102 - val_acc: 0.6964
#
# Epoch 00018: val_loss did not improve from 0.85649
# Epoch 19/50
#  - 33s - loss: 0.8651 - acc: 0.6974 - val_loss: 0.8736 - val_acc: 0.7014
#
# Epoch 00019: val_loss did not improve from 0.85649
# Epoch 20/50
#  - 33s - loss: 0.8523 - acc: 0.7028 - val_loss: 0.8700 - val_acc: 0.7044
#
# Epoch 00020: val_loss did not improve from 0.85649
# Epoch 21/50
#  - 32s - loss: 0.8420 - acc: 0.7102 - val_loss: 0.8376 - val_acc: 0.7164
#
# Epoch 00021: val_loss improved from 0.85649 to 0.83763, saving model to model.weights.best.hdf5
# Epoch 22/50
#  - 50s - loss: 0.8329 - acc: 0.7136 - val_loss: 0.8197 - val_acc: 0.7176
#
# Epoch 00022: val_loss improved from 0.83763 to 0.81968, saving model to model.weights.best.hdf5
# Epoch 23/50
#  - 39s - loss: 0.8224 - acc: 0.7120 - val_loss: 0.8741 - val_acc: 0.6962
#
# Epoch 00023: val_loss did not improve from 0.81968
# Epoch 24/50
#  - 39s - loss: 0.8166 - acc: 0.7179 - val_loss: 0.8531 - val_acc: 0.7078
#
# Epoch 00024: val_loss did not improve from 0.81968
# Epoch 25/50
#  - 42s - loss: 0.8022 - acc: 0.7210 - val_loss: 0.8568 - val_acc: 0.7046
#
# Epoch 00025: val_loss did not improve from 0.81968
# Epoch 26/50
#  - 39s - loss: 0.8002 - acc: 0.7211 - val_loss: 0.8260 - val_acc: 0.7170
#
# Epoch 00026: val_loss did not improve from 0.81968
# Epoch 27/50
#  - 40s - loss: 0.7888 - acc: 0.7268 - val_loss: 0.8359 - val_acc: 0.7122
#
# Epoch 00027: val_loss did not improve from 0.81968
# Epoch 28/50
#  - 39s - loss: 0.7803 - acc: 0.7310 - val_loss: 0.8464 - val_acc: 0.7162
#
# Epoch 00028: val_loss did not improve from 0.81968
# Epoch 29/50
#  - 39s - loss: 0.7808 - acc: 0.7309 - val_loss: 0.8517 - val_acc: 0.7148
#
# Epoch 00029: val_loss did not improve from 0.81968
# Epoch 30/50
#  - 39s - loss: 0.7742 - acc: 0.7316 - val_loss: 0.8235 - val_acc: 0.7128
#
# Epoch 00030: val_loss did not improve from 0.81968
# Epoch 31/50
#  - 39s - loss: 0.7661 - acc: 0.7370 - val_loss: 0.8512 - val_acc: 0.7038
#
# Epoch 00031: val_loss did not improve from 0.81968
# Epoch 32/50
#  - 39s - loss: 0.7635 - acc: 0.7369 - val_loss: 0.8915 - val_acc: 0.6944
#
# Epoch 00032: val_loss did not improve from 0.81968
# Epoch 33/50
#  - 40s - loss: 0.7645 - acc: 0.7367 - val_loss: 0.8216 - val_acc: 0.7224
#
# Epoch 00033: val_loss did not improve from 0.81968
# Epoch 34/50
#  - 40s - loss: 0.7571 - acc: 0.7397 - val_loss: 0.8309 - val_acc: 0.7132
#
# Epoch 00034: val_loss did not improve from 0.81968
# Epoch 35/50
#  - 40s - loss: 0.7475 - acc: 0.7412 - val_loss: 0.8609 - val_acc: 0.7074
#
# Epoch 00035: val_loss did not improve from 0.81968
# Epoch 36/50
#  - 40s - loss: 0.7482 - acc: 0.7422 - val_loss: 0.8062 - val_acc: 0.7234
#
# Epoch 00036: val_loss improved from 0.81968 to 0.80621, saving model to model.weights.best.hdf5
# Epoch 37/50
#  - 40s - loss: 0.7397 - acc: 0.7477 - val_loss: 0.8335 - val_acc: 0.7144
#
# Epoch 00037: val_loss did not improve from 0.80621
# Epoch 38/50
#  - 40s - loss: 0.7335 - acc: 0.7479 - val_loss: 0.8182 - val_acc: 0.7176
#
# Epoch 00038: val_loss did not improve from 0.80621
# Epoch 39/50
#  - 39s - loss: 0.7209 - acc: 0.7518 - val_loss: 0.8477 - val_acc: 0.7112
#
# Epoch 00039: val_loss did not improve from 0.80621
# Epoch 40/50
#  - 40s - loss: 0.7225 - acc: 0.7522 - val_loss: 0.7936 - val_acc: 0.7244
#
# Epoch 00040: val_loss improved from 0.80621 to 0.79359, saving model to model.weights.best.hdf5
# Epoch 41/50
#  - 40s - loss: 0.7240 - acc: 0.7518 - val_loss: 0.8344 - val_acc: 0.7142
#
# Epoch 00041: val_loss did not improve from 0.79359
# Epoch 42/50
#  - 39s - loss: 0.7149 - acc: 0.7535 - val_loss: 0.8100 - val_acc: 0.7254
#
# Epoch 00042: val_loss did not improve from 0.79359
# Epoch 43/50
#  - 39s - loss: 0.7159 - acc: 0.7558 - val_loss: 0.8428 - val_acc: 0.7088
#
# Epoch 00043: val_loss did not improve from 0.79359
# Epoch 44/50
#  - 40s - loss: 0.7110 - acc: 0.7544 - val_loss: 0.8051 - val_acc: 0.7288
#
# Epoch 00044: val_loss did not improve from 0.79359
# Epoch 45/50
#  - 46s - loss: 0.6999 - acc: 0.7604 - val_loss: 0.8173 - val_acc: 0.7286
#
# Epoch 00045: val_loss did not improve from 0.79359
# Epoch 46/50
#  - 34s - loss: 0.7095 - acc: 0.7576 - val_loss: 0.7976 - val_acc: 0.7294
#
# Epoch 00046: val_loss did not improve from 0.79359
# Epoch 47/50
#  - 32s - loss: 0.6898 - acc: 0.7654 - val_loss: 0.8237 - val_acc: 0.7228
#
# Epoch 00047: val_loss did not improve from 0.79359
# Epoch 48/50
#  - 38s - loss: 0.7000 - acc: 0.7614 - val_loss: 0.7932 - val_acc: 0.7316
#
# Epoch 00048: val_loss improved from 0.79359 to 0.79318, saving model to model.weights.best.hdf5
# Epoch 49/50
#  - 32s - loss: 0.6887 - acc: 0.7621 - val_loss: 0.8187 - val_acc: 0.7216
#
# Epoch 00049: val_loss did not improve from 0.79318
# Epoch 50/50
#  - 32s - loss: 0.6872 - acc: 0.7665 - val_loss: 0.8102 - val_acc: 0.7262
#
# Epoch 00050: val_loss did not improve from 0.79318

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7178

# %%
score = model.evaluate(x_train, y_train, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.8479333333333333

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)  #like predict perpba

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
y_hat.shape
# Out:
# (10000, 10)

# %%
y_hat[0].argmax()
# Out:
# 3

# %%
y_hat[0]
# Out:
# array([3.2748634e-03, 5.9451215e-04, 4.7148135e-03, 5.9590179e-01,
#        2.2660985e-03, 2.2078983e-01, 1.7464364e-02, 8.3196803e-04,
#        1.4844610e-01, 5.7156747e-03], dtype=float32)

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
